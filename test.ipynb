# %%
import sqlite3
import pandas as pd


con = sqlite3.connect("./AutoTrader.db")



vehicle_df = pd.read_sql_query("SELECT * FROM vehicles", con)

titles = vehicle_df.title


years = []
i = 0
for x in titles:

  year = x[:4]
  years.append(year) if year not in years else years
  vehicle_df["year"][i] = year
  i += 1

  
years.sort()
# Out:
# /tmp/ipykernel_1560/1821437374.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicle_df["year"][i] = year

# %%
print(vehicle_df)
# Out:
#              id                                              title  make  \
# 0      10218564        2010 Hyundai Tucson AWD 4dr I4 Auto Limited  None
# 1      10235190                2015 Cadillac Escalade 4WD 4dr Base  None
# 2      10289127                           2006 Mercedes-Benz SL500  None
# 3      10296405                       2012 Honda CR-V AWD 5dr EX-L  None
# 4      10316488                                 2017 Tesla Model S  None
# ...         ...                                                ...   ...
# 62017  76935001  2022 Audi Q7 55 3.0T Komfort quattro 8sp Tiptr...  None
# 62018  76935002  2022 Audi Q5 45 2.0T Progressiv quattro 7sp S ...  None
# 62019  76935003  2022 Audi A5 Sportback 45 2.0T Progressiv quat...  None
# 62020  76935004               2020 Audi Q3 Technik 45 TFSI quattro  None
# 62021  76935025             2017 Volvo XC60 T6 Drive-E AWD Premier  None
#
#        year    price                                               link  \
# 0      2010  $12,000  /a/hyundai/tucson/north%20york/ontario/19_1021...
# 1      2015  $61,999  /a/cadillac/escalade/thornhill/ontario/19_1023...
# 2      2006  $29,500  /a/mercedes-benz/sl-class/woodbridge/ontario/1...
# 3      2012  $11,000  /a/honda/cr-v/thornhill/ontario/19_10296405_/?...
# 4      2017  $88,000  /a/tesla/model%20s/north%20york/ontario/19_103...
# ...     ...      ...                                                ...
# 62017  2022  $82,888  /a/audi/q7/newmarket/ontario/5_56935001_201409...
# 62018  2022  $58,839  /a/audi/q5/newmarket/ontario/5_56935002_201409...
# 62019  2022  $62,779  /a/audi/a5/newmarket/ontario/5_56935003_201409...
# 62020  2020  $46,896  /a/audi/q3/calgary/alberta/5_56935004_20080421...
# 62021  2017  $24,250  /a/volvo/xc60/hamilton/ontario/5_56935025_2019...
#
#                                       odometer
# 0      Mileage 172,000 km\n North York ∙ 10 km
# 1       Mileage 101,000 km\n Thornhill ∙ 13 km
# 2       Mileage 83,500 km\n Woodbridge ∙ 24 km
# 3       Mileage 220,000 km\n Thornhill ∙ 14 km
# 4        Mileage 65,000 km\n North York ∙ 2 km
# ...                                        ...
# 62017
# 62018
# 62019
# 62020    Mileage 23,099 km Certified Pre-Owned
# 62021                       Mileage 143,627 km
#
# [62022 rows x 7 columns]

# %%
makes = [
    "Abarth",
    "Alfa Romeo",
    "Aston Martin",
    "Audi",
    "Bentley",
    "BMW",
    "Bugatti",
    "Cadillac",
    "Chevrolet",
    "Chrysler",
    "Citroën",
    "Dacia",
    "Daewoo",
    "Daihatsu",
    "Dodge",
    "Donkervoort",
    "DS",
    "Ferrari",
    "Fiat",
    "Fisker",
    "Ford",
    "Honda",
    "Hummer",
    "Hyundai",
    "Infiniti",
    "Iveco",
    "Jaguar",
    "Jeep",
    "Kia",
    "KTM",
    "Lada",
    "Lamborghini",
    "Lancia",
    "Land Rover",
    "Landwind",
    "Lexus",
    "Lotus",
    "Maserati",
    "Maybach",
    "Mazda",
    "McLaren",
    "Mercedes-Benz",
    "MG",
    "Mini",
    "Mitsubishi",
    "Morgan",
    "Nissan",
    "Opel",
    "Peugeot",
    "Pontiac",
    "Porsche",
    "Renault",
    "Rolls-Royce",
    "Rover",
    "Saab",
    "Seat",
    "Skoda",
    "Smart",
    "SsangYong",
    "Subaru",
    "Suzuki",
    "Tesla",
    "Toyota",
    "Volkswagen",
    "Volvo",
    "Oldsmobile"
    "Toyota",
    "Ford",
    "Chevrolet",
    "Honda",
    "Nissan",
    "Hyundai",
    "Kia",
    "Subaru",
    "Mazda",
    "Volkswagen",
    "Mercedes-Benz",
    "BMW",
    "Audi",
    "Porsche",
    "Volvo",
    "Jaguar",
    "Land Rover",
    "Tesla",
    "Lexus",
    "Mini",
    "Mitsubishi",
    "Infiniti",
    "Buick",
    "Cadillac",
    "GMC",
    "Ram",
    "Dodge",
    "Jeep",
    "Chrysler",
    "Fiat",
    "Alfa Romeo",
    "Maserati",
    "Lancia",
    "Ferrari",
    "Lamborghini",
    "Bugatti",
    "Rolls-Royce",
    "Bentley",
    "Aston Martin",
    "McLaren",
    "Lotus",
    "Koenigsegg",
    "Pagani",
    "Rimac",
    "Zenvo",
    "Apollo",
    "Spyker",
    "Gumpert",
    "SSC North America",
    "Noble",
    "Westfield",
    "Ariel",
    "Radical",
    "Caterham",
    "Morgan",
    "DS Automobiles",
    "Peugeot",
    "Citroën",
    "Renault",
    "Dacia",
    "Opel",
    "Vauxhall",
    "Skoda",
    "Seat",
    "Abarth",
    "Alpina",
    "DS Automobiles",
    "Smart",
    "Lada",
    "GAZ",
    "UAZ",
    "Lada",
    "Great Wall",
    "Geely",
    "BYD",
    "Lifan",
    "Chery",
    "Changan",
    "Roewe",
    "Haval",
    "MG",
    "Qoros",
    "JAC",
    "GAC",
    "Changhe",
    "Gonow",
    "JMC",
    "Borgward",
    "BAIC",
    "Foton",
    "Sinomach",
    "Changfeng",
    "Geely Emgrand",
    "ZX Auto",
    "Haima",
    "Foday",
    "Dadi",
    "Yema",
    "Beiqi Foton",
    "Beijing Automobile Industry Holding",
    "Beijing Hyundai",
    "Beijing Benz",
    "Beijing JMA",
    "Beijing Automobile Works",
    "Beijing Changfeng",
    "Beijing Automobile International Corporation",
    "Beijing Great Wall",
    "Beijing Land Rover",
    "Beijing Toyota",
    "Beijing Jeep",
    "Beijing Automobile Industry Corporation",
]
makes = list(dict.fromkeys(makes))

# %%
i = 0
for word in titles:
  make_match = [word for word in makes if word in vehicle_df.title[i]]
  make_match = ''.join(make_match)
  vehicle_df["make"][i] = make_match

  i += 1


vehicle_df.head(200)
# Out:
# /tmp/ipykernel_1560/2605501102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicle_df["make"][i] = make_match
#            id                                        title           make  \
# 0    10218564  2010 Hyundai Tucson AWD 4dr I4 Auto Limited        Hyundai
# 1    10235190          2015 Cadillac Escalade 4WD 4dr Base       Cadillac
# 2    10289127                     2006 Mercedes-Benz SL500  Mercedes-Benz
# 3    10296405                 2012 Honda CR-V AWD 5dr EX-L          Honda
# 4    10316488                           2017 Tesla Model S          Tesla
# ..        ...                                          ...            ...
# 195  11907018               1979 Ford Thunderbird Burgundy           Ford
# 196  11908390    2013 BMW 5 Series 4dr Sdn 528i xDrive AWD            BMW
# 197  11908632             2013 Hyundai Santa Fe Sport Base        Hyundai
# 198  11909516                         2009 BMW 335i xDrive            BMW
# 199  11909865              2005 Chevrolet Corvette 2dr Cpe      Chevrolet
#
#      year    price                                               link  \
# 0    2010  $12,000  /a/hyundai/tucson/north%20york/ontario/19_1021...
# 1    2015  $61,999  /a/cadillac/escalade/thornhill/ontario/19_1023...
# 2    2006  $29,500  /a/mercedes-benz/sl-class/woodbridge/ontario/1...
# 3    2012  $11,000  /a/honda/cr-v/thornhill/ontario/19_10296405_/?...
# 4    2017  $88,000  /a/tesla/model%20s/north%20york/ontario/19_103...
# ..    ...      ...                                                ...
# 195  1979   $4,000  /a/ford/thunderbird/calgary/alberta/19_1190701...
# 196  2013  $12,000  /a/bmw/5%20series/woodbridge/ontario/19_119083...
# 197  2013  $11,999  /a/hyundai/santa%20fe%20sport/markham/ontario/...
# 198  2009  $16,000  /a/bmw/3%20series/london/ontario/19_11909516_/...
# 199  2005  $69,998  /a/chevrolet/corvette/surrey/british%20columbi...
#
#                                     odometer
# 0    Mileage 172,000 km\n North York ∙ 10 km
# 1     Mileage 101,000 km\n Thornhill ∙ 13 km
# 2     Mileage 83,500 km\n Woodbridge ∙ 24 km
# 3     Mileage 220,000 km\n Thornhill ∙ 14 km
# 4      Mileage 65,000 km\n North York ∙ 2 km
# ..                                       ...
# 195   Mileage 78,000 km\n Calgary ∙ 2,703 km
# 196  Mileage 201,000 km\n Woodbridge ∙ 24 km
# 197     Mileage 112,900 km\n Markham ∙ 20 km
# 198     Mileage 170,000 km\n London ∙ 172 km
# 199    Mileage 16,600 km\n Surrey ∙ 3,336 km
#
# [200 rows x 7 columns]

# %%
import os
vehicle_models_master_df = []
for file in os.listdir('us-car-models-data'):
  f = os.path.join('us-car-models-data', file)
  if f.endswith('.csv'):
  
    vehicle_models_master_df.append(pd.read_csv(f))
vehicle_models_master_df = pd.concat(vehicle_models_master_df, ignore_index=True)

models_df = vehicle_models_master_df
models_df
# Out:
#        year        make      model             body_styles
# 0      1992       Acura    Integra  ["Sedan", "Hatchback"]
# 1      1992       Acura     Legend      ["Sedan", "Coupe"]
# 2      1992       Acura        NSX               ["Coupe"]
# 3      1992       Acura      Vigor               ["Sedan"]
# 4      1992  Alfa Romeo        164               ["Sedan"]
# ...     ...         ...        ...                     ...
# 11080  2024       MAZDA      CX-70                 ["SUV"]
# 11081  2024    Polestar          5               ["Sedan"]
# 11082  2024      Subaru  Crosstrek                 ["SUV"]
# 11083  2024  Volkswagen    ID.Buzz         ["Van/Minivan"]
# 11084  2024       Volvo       EX90                 ["SUV"]
#
# [11085 rows x 4 columns]

# %%
models = models_df.loc[models_df["make"] == "Ford"].model
print(models)
# Out:
# 95                        Aerostar Cargo
# 96                    Aerostar Passenger
# 97                                Bronco
# 98                            Club Wagon
# 99                        Crown Victoria
#                       ...
# 10833                    Ranger SuperCab
# 10834                   Ranger SuperCrew
# 10835          Transit Connect Cargo Van
# 10836    Transit Connect Passenger Wagon
# 11072                            Mustang
# Name: model, Length: 935, dtype: object

# %%
i = 0
for make in vehicle_df.make:
  # for year in vehicle_df.year:

    models = models_df.loc[models_df["make"] == make].model
    # models = models.loc[models["year"] == year]
    model_match = [word for word in models if word in vehicle_df.title[i]]
    i += 1
    print(model_match)
# Out:
# ['Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson']
# ['Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade']
# ['SL', 'SL', 'SL', 'SL']
# ['CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V', 'CR-V']
# ['Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S']
# ['M', 'M', 'M']
# []
# []
# ['911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911']
# ['A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7']
# ['911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911']
# ['SL', 'SL', 'SL', 'SL']
# []
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'GT', 'Mustang', 'GT', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# ['SX4', 'SX4', 'SX4', 'SX4', 'SX4', 'SX4', 'SX4']
# ['3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', 'M', '3 Series', 'M', '3 Series', 'M', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series']
# []
# ['Forte', 'Forte', 'Forte', 'Forte', 'Forte', 'Forte', 'Forte5', 'Forte', 'Forte5', 'Forte', 'Forte5', 'Forte', 'Forte5', 'Forte', 'Forte', 'Forte', 'Forte', 'Forte']
# []
# ['M', 'M', 'M']
# ['Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata']
# []
# ['Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord']
# []
# ['Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna']
# ['Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox']
# ['Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg']
# []
# ['Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey']
# ['M', 'M', 'M']
# ['Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S']
# ['SL', 'SLK', 'SL', 'SL', 'SL']
# []
# []
# ['Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey']
# []
# ['Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta']
# ['3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', 'M', '3 Series', 'M', '3 Series', 'M', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series']
# ['Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic']
# []
# []
# ['Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry Hybrid', 'Camry', 'Camry Hybrid', 'Camry', 'Camry Hybrid', 'Camry', 'Camry Hybrid', 'Camry', 'Camry Hybrid', 'Camry', 'Camry Hybrid', 'Camry', 'Camry Hybrid']
# ['Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro']
# ['S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8', 'S8']
# ['RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX']
# ['1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab', '1500 Quad Cab']
# []
# ['Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze']
# []
# ['S3', 'S3', 'S3', 'S3', 'S3', 'S3', 'S3']
# []
# []
# ['CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS']
# ['Caliber', 'Caliber', 'Caliber', 'Caliber', 'Caliber', 'Caliber']
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90', 'XC90']
# []
# []
# ['Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic']
# ['Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL']
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf']
# ['Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer']
# ['Ghost', 'Ghost', 'Ghost', 'Ghost', 'Ghost', 'Ghost', 'Ghost', 'Ghost', 'Ghost', 'Ghost', 'Ghost', 'Ghost']
# []
# ['RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4 Hybrid', 'RAV4', 'RAV4 Hybrid', 'RAV4', 'RAV4 Hybrid', 'RAV4', 'RAV4 Hybrid', 'RAV4', 'RAV4 Hybrid', 'RAV4', 'RAV4 Hybrid', 'RAV4', 'RAV4 Hybrid']
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# []
# ['BRZ', 'BRZ', 'BRZ', 'BRZ', 'BRZ', 'BRZ', 'BRZ', 'BRZ', 'BRZ', 'BRZ']
# []
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# ['RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX']
# ['Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey']
# ['Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg', 'Touareg']
# []
# ['A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5']
# []
# ['Aerio', 'Aerio', 'Aerio', 'Aerio', 'Aerio', 'Aerio']
# ['Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze']
# ['A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4']
# []
# ['A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7']
# ['3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', 'M', '3 Series', 'M', '3 Series', 'M', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series']
# ['Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson', 'Tucson']
# []
# ['Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion']
# []
# ['3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', 'M', '3 Series', 'M', '3 Series', 'M', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series']
# ['M', 'M', 'M']
# ['SSR', 'SSR', 'SSR', 'SSR', 'SS', 'SS', 'SS', 'SS']
# []
# ['M3', 'M3', 'M3', 'M3', 'M3', 'M', 'M', 'M3', 'M', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3']
# ['M', 'M', 'M', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series']
# ['Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', 'Sebring', '200', '200', '200', '200', '200', '200', '200']
# ['XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ']
# ['M', 'M', 'M']
# []
# []
# ['Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion']
# ['SL', 'SL', 'SL', 'SL']
# ['Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox']
# ['Beetle', 'Beetle', 'Beetle', 'Beetle', 'Beetle', 'Beetle', 'Beetle', 'Beetle']
# []
# ['Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer']
# []
# ['Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Grand Cherokee']
# ['M', 'M', 'M', 'i8', 'i8', 'i8', 'i8', 'i8']
# ['Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla']
# ['M3', 'M3', 'M3', 'M3', 'M3', 'M', 'M', 'M3', 'M', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3']
# ['A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5', 'A5']
# []
# ['3 Series', '3 Series', '3 Series', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M', '3 Series', 'M', 'M3', '3 Series', 'M', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3', '3 Series', '3 Series', '3 Series', 'M3', '3 Series', 'M3', '3 Series', 'M3']
# ['Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5']
# ['GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS', 'GS']
# ['Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy']
# ['Atlas', 'Atlas', 'Atlas', 'Atlas', 'Atlas', 'Atlas']
# ['GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI', 'GTI']
# ['TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT']
# ['S5', 'S5', 'S5', 'S5', 'S5', 'S5', 'S5', 'S5', 'S5', 'S5', 'S5', 'S5', 'S5', 'S5', 'S5']
# []
# ['Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder', 'Pathfinder']
# []
# ['Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus', 'Focus']
# ['Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey']
# ['Escalade', 'Escalade', 'Escalade', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV', 'Escalade', 'Escalade ESV']
# ['Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord']
# []
# ['Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S']
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'GT', 'Mustang', 'GT', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# ['Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey']
# ['M', 'M', 'M']
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['Genesis', 'Genesis', 'Genesis Coupe', 'Genesis', 'Genesis Coupe', 'Genesis', 'Genesis Coupe', 'Genesis', 'Genesis Coupe', 'Genesis', 'Genesis Coupe', 'Genesis', 'Genesis Coupe', 'Genesis', 'Genesis Coupe']
# []
# ['Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander']
# ['Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander']
# ['3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', 'M', '3 Series', 'M', '3 Series', 'M', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series']
# []
# ['Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne']
# ['California', 'California', 'California', 'California', 'California', 'California', 'California', 'California', 'California']
# []
# []
# []
# ['Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne']
# []
# []
# []
# ['Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue']
# []
# ['Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano', 'Murano']
# []
# ['S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4']
# ['Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla']
# ['Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima', 'Optima']
# ['Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza']
# ['Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline', 'Ridgeline']
# ['Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion']
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'GT', 'Mustang', 'GT', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# ['RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX']
# []
# ['Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S', 'Model S']
# []
# []
# []
# ['M', 'M', 'M', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1']
# []
# []
# ['M', 'M', 'M']
# ['Quattro', 'Quattro', 'Quattro', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6', 'S6']
# ['Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'WRX', 'Impreza', 'WRX', 'Impreza', 'WRX', 'Impreza', 'WRX', 'Impreza', 'WRX', 'Impreza', 'WRX', 'Impreza', 'WRX', 'Impreza', 'WRX', 'Impreza', 'WRX']
# []
# []
# ['M', 'M', 'M']
# ['Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord']
# ['Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata', 'Sonata']
# ['ATS', 'ATS', 'ATS', 'ATS', 'ATS', 'ATS', 'ATS']
# ['Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro']
# ['M', 'X5', 'M', 'X5', 'M', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5']
# ['Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7']
# ['Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima', 'Altima']
# ['IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS F', 'IS', 'IS F', 'IS', 'IS F', 'IS', 'IS F', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS']
# ['911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911']
# ['200', '200', '200', '200', '200', '200', '200']
# ['M', 'M', 'M', 'i3', 'i3', 'i3', 'i3', 'i3', 'i3', 'i3']
# ['M', 'M', 'M', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4']
# []
# ['Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra', 'Sentra']
# ['M', 'X5', 'M', 'X5', 'M', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5', 'X5']
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid']
# ['Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf', 'Golf']
# ['GLC', 'GLC', 'GLC', 'GLC', 'GLC', 'GLC', 'GLC', 'GLC']
# ['Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic']
# ['3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', 'M', '3 Series', 'M', '3 Series', 'M', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series']
# ['Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7', 'Q7']
# ['Thunderbird', 'Thunderbird', 'Thunderbird', 'Thunderbird', 'Thunderbird', 'Thunderbird', 'Thunderbird', 'Thunderbird', 'Thunderbird', 'Thunderbird']
# ['5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', 'M', '5 Series', 'M', '5 Series', 'M', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series', '5 Series']
# ['Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe Sport', 'Santa Fe', 'Santa Fe Sport', 'Santa Fe', 'Santa Fe Sport', 'Santa Fe', 'Santa Fe Sport', 'Santa Fe', 'Santa Fe Sport', 'Santa Fe', 'Santa Fe Sport', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe']
# ['M', 'M', 'M']
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS', 'CTS-V', 'CTS', 'CTS-V', 'CTS', 'CTS-V', 'CTS', 'CTS-V']
# ['M', 'M', 'M', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1', 'X1']
# []
# ['GLA', 'GLA', 'GLA', 'GLA', 'GLA', 'GLA', 'GLA', 'GLA']
# ['TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT']
# []
# []
# ['Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer', 'Explorer']
# ['Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic']
# ['GLI', 'GLI']
# ['Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger']
# ['SL', 'SL', 'SL', 'SL']
# []
# ['Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger']
# ['370Z', '370Z', '370Z', '370Z', '370Z', '370Z', '370Z', '370Z', '370Z', '370Z', '370Z', '370Z', 'Z']
# ['TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT', 'TT']
# ['Lumina', 'Lumina', 'Lumina', 'Lumina', 'Lumina', 'Lumina', 'Lumina', 'Lumina', 'Lumina', 'Lumina']
# []
# ['XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ', 'XJ']
# ['Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic']
# ['DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille', 'DeVille']
# []
# ['600LT']
# ['UX', 'UX', 'UX', 'UX', 'UX']
# []
# []
# ['M', 'M', 'M', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series', '4 Series']
# ['IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS', 'IS']
# ['Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte']
# ['M', 'M', 'M']
# []
# ['E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class', 'E-Class']
# ['Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman']
# ['Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla']
# ['M', 'M', 'M']
# []
# ['M', 'M', 'M', '2 Series', '2 Series', '2 Series', 'M2', '2 Series', 'M2', '2 Series', 'M2', '2 Series', 'M2', '2 Series', 'M2', '2 Series', 'M2', '2 Series', '2 Series']
# []
# ['Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman', 'Cayman']
# []
# []
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['M', 'M', 'M']
# ['C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70']
# []
# []
# []
# ['Avalanche', 'Avalanche', 'Avalanche', 'Avalanche', 'Avalanche', 'Avalanche', 'Avalanche']
# ['XT5', 'XT5', 'XT5', 'XT5', 'XT5', 'XT5', 'XT5']
# ['Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback']
# []
# ['Beetle', 'Beetle', 'Beetle', 'Beetle', 'Beetle', 'Beetle', 'Beetle', 'Beetle']
# ['Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe']
# ['Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue', 'Rogue']
# []
# ['Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta']
# []
# ['Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte', 'Quattroporte']
# ['Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave', 'Enclave']
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic']
# ['M', 'M', 'M']
# ['Bolt EV', 'Bolt EV', 'Bolt EV', 'Bolt EV', 'Bolt EV', 'Bolt EV', 'Bolt EV']
# ['GLS', 'GLS', 'GLS', 'GLS', 'GLS', 'GLS', 'GLS']
# ['Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL', 'Yukon', 'Yukon XL']
# []
# []
# []
# []
# ['Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra', 'Xterra']
# ['R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8']
# []
# []
# ['M', 'M', 'M', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4', 'Z4']
# ['ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES']
# ['911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911']
# []
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'GT', 'Mustang', 'GT', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# ['C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class', 'C-Class']
# ['Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro']
# []
# ['R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8']
# ['SL', 'SL', 'SL', 'SL']
# []
# ['Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback']
# ['Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge', 'Edge']
# ['Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara']
# ['3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', 'M', '3 Series', 'M', '3 Series', 'M', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series']
# ['Q3', 'Q3', 'Q3', 'Q3', 'Q3', 'Q3', 'Q3', 'Q3', 'Q3']
# []
# []
# ['Firebird', 'Firebird', 'Firebird', 'Firebird', 'Firebird', 'Firebird', 'Firebird', 'Firebird', 'Firebird', 'Firebird', 'Firebird']
# []
# []
# []
# ['Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback']
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'Monte Carlo', 'SS', 'SS', 'SS', 'SS']
# []
# ['Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla']
# ['RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4', 'RAV4']
# ['Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna', 'Sienna']
# ['Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe']
# ['Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback', 'Outback']
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# []
# []
# []
# []
# []
# ['Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius', 'Prius']
# ['Spark', 'Spark', 'Spark', 'Spark', 'Spark', 'Spark', 'Spark', 'Spark', 'Spark', 'Spark', 'Spark']
# ['GLC', 'GLC', 'GLC', 'GLC', 'GLC', 'GLC', 'GLC', 'GLC']
# []
# ['M3', 'M3', 'M3', 'M3', 'M3', 'M', 'M', 'M3', 'M', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3', 'M3']
# ['DB9', 'DB9', 'DB9', 'DB9', 'DB9', 'DB9', 'DB9', 'DB9', 'DB9', 'DB9', 'DB9']
# ['Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry', 'Camry']
# []
# ['Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne', 'Cayenne']
# ['M', 'M', 'M', 'i8', 'i8', 'i8', 'i8', 'i8']
# []
# []
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX', 'RX']
# ['Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5']
# []
# ['S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4', 'S4']
# ['S2000', 'S2000', 'S2000', 'S2000', 'S2000', 'S2000', 'S2000', 'S2000', 'S2000', 'S2000']
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage', 'Sportage']
# ['B-Class', 'B-Class', 'B-Class', 'B-Class']
# ['R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8']
# ['M', 'M', 'M', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3', 'X3']
# []
# ['Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord']
# []
# ['Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain', 'Terrain']
# []
# ['Routan', 'Routan', 'Routan', 'Routan', 'Routan', 'Routan']
# ['Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey']
# ...
# ['M', 'M', 'M']
# ['M', 'M', 'M']
# []
# ['G6', 'G6', 'G6', 'G6', 'G6', 'G6']
# []
# ['Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid', 'Highlander', 'Highlander Hybrid']
# ['Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey', 'Odyssey']
# []
# ['Taycan', 'Taycan', 'Taycan']
# ['911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911']
# ['Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox', 'Equinox']
# []
# ['Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic']
# []
# ['Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia', 'Acadia']
# ['Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy']
# ['M', 'M', 'M']
# ['Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey', 'Journey']
# []
# ['Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger', 'Charger']
# ['R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8']
# ['911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911', '911']
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# ['Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger', 'Challenger']
# ['Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5', 'Q5']
# ['Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara', 'Grand Vitara']
# []
# ['Q8', 'Q8', 'Q8', 'SQ8', 'Q8', 'SQ8', 'Q8', 'SQ8']
# ['Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe XL', 'Santa Fe', 'Santa Fe', 'Santa Fe', 'Santa Fe']
# ['Model X', 'Model X', 'Model X', 'Model X', 'Model X', 'Model X', 'Model X', 'Model X']
# []
# []
# []
# ['Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra', 'Elantra']
# ['Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Grand Cherokee']
# ['M', 'M', 'M']
# ['M', 'M', 'M']
# ['200', '200', '200', '200', '200', '200', '200']
# ['Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic']
# []
# []
# []
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# ['M', 'M', 'M']
# ['ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES', 'ES']
# ['Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria', 'Crown Victoria']
# []
# []
# []
# ['Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion', 'Fusion']
# ['PT Cruiser', 'PT Cruiser', 'PT Cruiser', 'PT Cruiser', 'PT Cruiser', 'PT Cruiser', 'PT Cruiser', 'PT Cruiser', 'PT Cruiser', 'PT Cruiser', '200', '200', '200', '200', '200', '200', '200']
# ['Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper', 'Viper']
# ['Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang', 'Mustang']
# []
# ['Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy', 'Legacy']
# []
# ['Huracan', 'Huracan', 'Huracan', 'Huracan', 'Huracan', 'Huracan', 'Huracan']
# ['7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', 'M', '7 Series', 'M', '7 Series', 'M', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series', '7 Series']
# ['Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord', 'Accord']
# []
# ['3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', 'M', '3 Series', 'M', '3 Series', 'M', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series', '3 Series']
# ['M', 'M', 'M']
# []
# ['Macan', 'Macan', 'Macan', 'Macan', 'Macan', 'Macan', 'Macan', 'Macan', 'Macan']
# ['Fiesta', 'Fiesta', 'Fiesta', 'Fiesta', 'Fiesta', 'Fiesta', 'Fiesta', 'Fiesta', 'Fiesta']
# []
# ['Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro', 'Camaro']
# ['Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic', 'Civic']
# ['C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'C70']
# ['Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon', 'Avalon']
# []
# ['Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze', 'Cruze']
# ['Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta', 'Jetta']
# []
# []
# []
# ['Avenger', 'Avenger', 'Avenger', 'Avenger', 'Avenger', 'Avenger', 'Avenger', 'Avenger', 'Avenger', 'Avenger', 'Avenger', 'Avenger', 'Avenger']
# ['Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Cherokee', 'Grand Cherokee', 'Grand Cherokee']
# ['R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8', 'R8']
# ['A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4']
# ['Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza', 'Impreza']
# []
# ['Genesis', 'Genesis', 'Genesis', 'Genesis', 'Genesis', 'Genesis', 'Genesis', 'Genesis']
# ['Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent', 'Accent']
# []
# ['C70', 'C70', 'C70', 'C70', 'C70', 'C70', 'XC70', 'C70', 'XC70', 'XC70', 'C70', 'XC70', 'C70', 'XC70', 'C70', 'XC70', 'C70', 'XC70', 'C70', 'XC70', 'C70', 'XC70', 'C70', 'XC70', 'C70', 'XC70', 'XC70', 'XC70', 'XC70']
# []
# ['Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country', 'Town & Country']
# []
# ['Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot', 'Pilot']
# []
# []
# ['Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette', 'Corvette']
# ['M', 'M', 'M']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 5
#       1 i = 0
#       2 for make in vehicle_df.make:
#       3   # for year in vehicle_df.year:
# ----> 5     models = models_df.loc[models_df["make"] == make].model
#       6     # models = models.loc[models["year"] == year]
#       7     model_match = [word for word in models if word in vehicle_df.title[i]]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:43, in OpsMixin.__eq__(self, other)
#      41 @unpack_zerodim_and_defer("__eq__")
#      42 def __eq__(self, other):
# ---> 43     return self._cmp_method(other, operator.eq)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:6246, in Series._cmp_method(self, other, op)
#    6243 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6245 with np.errstate(all="ignore"):
# -> 6246     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6248 return self._construct_result(res_values, name=res_name)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# KeyboardInterrupt:
